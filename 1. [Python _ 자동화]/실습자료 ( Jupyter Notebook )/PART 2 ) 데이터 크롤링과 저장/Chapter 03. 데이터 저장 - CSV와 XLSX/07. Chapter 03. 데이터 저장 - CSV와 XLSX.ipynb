# %% [markdown]
# # csv와 xlsx 저장하기

# %% [markdown]
# * 다음 금융에서 kospi 데이터를 가져오기 위해서 requests 라이브러리를 사용합니다.

# %%
import requests

# %%
url = 'http://finance.daum.net/api/market_index/days?page=1&perPage=100&market=KOSPI&pagination=true'
# 헤더 정보 설정 수정
header = {'Accept' : 'application/json, text/javascript, */*; q=0.01',
            'Referer' :'http://finance.daum.net/domestic/kospi',
            'User-Agent' : 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/75.0.3770.100 Safari/537.36',
            'X-Requested-With' : 'XMLHttpRequest'}
r = requests.get(url, headers = header)

# %% [markdown]
# * json 라이브러리의 loads 함수는 문자열로 된 json 형태의 데이터를 dict객체로 변환시켜 줍니다.

# %%
import json

json_r = json.loads(r.text)

# %% [markdown]
# * dict 객체이므로 keys() 메소드를 사용하여 key값을 확인합니다.

# %%
json_r.keys()
# Out:
# dict_keys(['data', 'totalPages', 'currentPage', 'pageSize'])

# %% [markdown]
# * data 키만 출력합니다.

# %%
json_r['data']
# Out:
# [{'date': '2019-07-03 00:00:00',
#   'tradePrice': 2113.28,
#   'change': 'FALL',
#   'changePrice': 8.74,
#   'accTradeVolume': 180753,
#   'accTradePrice': 1415097,
#   'individualStraightPurchasePrice': 25435352963,
#   'foreignStraightPurchasePrice': -51579856319,
#   'institutionStraightPurchasePrice': 28986343951},
#  {'date': '2019-07-02 00:00:00',
#   'tradePrice': 2122.02,
#   'change': 'FALL',
#   'changePrice': 7.72,
#   'accTradeVolume': 460830,
#   'accTradePrice': 4107541,
#   'individualStraightPurchasePrice': 24006908061,
#   'foreignStraightPurchasePrice': 34321459071,
#   'institutionStraightPurchasePrice': -51500525649},
#  {'date': '2019-07-01 00:00:00',
#   'tradePrice': 2129.74,
#   'change': 'FALL',
#   'changePrice': 0.88,
#   'accTradeVolume': 412291,
#   'accTradePrice': 4730192,
#   'individualStraightPurchasePrice': -19121687014,
#   'foreignStraightPurchasePrice': 154486503785,
#   'institutionStraightPurchasePrice': 6138187770},
#  {'date': '2019-06-28 00:00:00',
#   'tradePrice': 2130.62,
#   'change': 'FALL',
#   'changePrice': 3.7,
#   'accTradeVolume': 537274,
#   'accTradePrice': 4282404,
#   'individualStraightPurchasePrice': -199483658718,
#   'foreignStraightPurchasePrice': 312263760802,
#   'institutionStraightPurchasePrice': -109684798220},
#  {'date': '2019-06-27 00:00:00',
#   'tradePrice': 2134.32,
#   'change': 'RISE',
#   'changePrice': 12.47,
#   'accTradeVolume': 644900,
#   'accTradePrice': 5122462,
#   'individualStraightPurchasePrice': -405768338937,
#   'foreignStraightPurchasePrice': 155887532000,
#   'institutionStraightPurchasePrice': 267089212849},
#  {'date': '2019-06-26 00:00:00',
#   'tradePrice': 2121.85,
#   'change': 'RISE',
#   'changePrice': 0.21,
#   'accTradeVolume': 736851,
#   'accTradePrice': 4455865,
#   'individualStraightPurchasePrice': -73635556218,
#   'foreignStraightPurchasePrice': 16452829619,
#   'institutionStraightPurchasePrice': 60969038311},
#  {'date': '2019-06-25 00:00:00',
#   'tradePrice': 2121.64,
#   'change': 'FALL',
#   'changePrice': 4.69,
#   'accTradeVolume': 642999,
#   'accTradePrice': 4249731,
#   'individualStraightPurchasePrice': -21135872689,
#   'foreignStraightPurchasePrice': 27387982,
#   'institutionStraightPurchasePrice': 8844220728},
#  {'date': '2019-06-24 00:00:00',
#   'tradePrice': 2126.33,
#   'change': 'RISE',
#   'changePrice': 0.71,
#   'accTradeVolume': 669639,
#   'accTradePrice': 4054920,
#   'individualStraightPurchasePrice': -72774648738,
#   'foreignStraightPurchasePrice': -99250349566,
#   'institutionStraightPurchasePrice': 163711527766},
#  {'date': '2019-06-21 00:00:00',
#   'tradePrice': 2125.62,
#   'change': 'FALL',
#   'changePrice': 5.67,
#   'accTradeVolume': 692027,
#   'accTradePrice': 5226303,
#   'individualStraightPurchasePrice': 118735540006,
#   'foreignStraightPurchasePrice': 13280881909,
#   'institutionStraightPurchasePrice': -130936554570},
#  {'date': '2019-06-20 00:00:00',
#   'tradePrice': 2131.29,
#   'change': 'RISE',
#   'changePrice': 6.51,
#   'accTradeVolume': 1007158,
#   'accTradePrice': 3994784,
#   'individualStraightPurchasePrice': -148542907457,
#   'foreignStraightPurchasePrice': -18322575414,
#   'institutionStraightPurchasePrice': 164450625338},
#  {'date': '2019-06-19 00:00:00',
#   'tradePrice': 2124.78,
#   'change': 'RISE',
#   'changePrice': 26.07,
#   'accTradeVolume': 862980,
#   'accTradePrice': 4984533,
#   'individualStraightPurchasePrice': -460489624085,
#   'foreignStraightPurchasePrice': 300430954174,
#   'institutionStraightPurchasePrice': 169276816225},
#  {'date': '2019-06-18 00:00:00',
#   'tradePrice': 2098.71,
#   'change': 'RISE',
#   'changePrice': 7.98,
#   'accTradeVolume': 600964,
#   'accTradePrice': 4579592,
#   'individualStraightPurchasePrice': -129501534187,
#   'foreignStraightPurchasePrice': 261816928364,
#   'institutionStraightPurchasePrice': 86891545505},
#  {'date': '2019-06-17 00:00:00',
#   'tradePrice': 2090.73,
#   'change': 'FALL',
#   'changePrice': 4.68,
#   'accTradeVolume': 561550,
#   'accTradePrice': 4255706,
#   'individualStraightPurchasePrice': 7838261537,
#   'foreignStraightPurchasePrice': -150088594638,
#   'institutionStraightPurchasePrice': 140374240557},
#  {'date': '2019-06-14 00:00:00',
#   'tradePrice': 2095.41,
#   'change': 'FALL',
#   'changePrice': 7.74,
#   'accTradeVolume': 473370,
#   'accTradePrice': 4716415,
#   'individualStraightPurchasePrice': 157690404429,
#   'foreignStraightPurchasePrice': -69368483603,
#   'institutionStraightPurchasePrice': -92172949183},
#  {'date': '2019-06-13 00:00:00',
#   'tradePrice': 2103.15,
#   'change': 'FALL',
#   'changePrice': 5.6,
#   'accTradeVolume': 553393,
#   'accTradePrice': 5998223,
#   'individualStraightPurchasePrice': 131707587548,
#   'foreignStraightPurchasePrice': -165712563303,
#   'institutionStraightPurchasePrice': 51511213419},
#  {'date': '2019-06-12 00:00:00',
#   'tradePrice': 2108.75,
#   'change': 'FALL',
#   'changePrice': 3.06,
#   'accTradeVolume': 693507,
#   'accTradePrice': 4661009,
#   'individualStraightPurchasePrice': -96265719945,
#   'foreignStraightPurchasePrice': -2329064115,
#   'institutionStraightPurchasePrice': 101634418700},
#  {'date': '2019-06-11 00:00:00',
#   'tradePrice': 2111.81,
#   'change': 'RISE',
#   'changePrice': 12.32,
#   'accTradeVolume': 550740,
#   'accTradePrice': 4276695,
#   'individualStraightPurchasePrice': -266518306801,
#   'foreignStraightPurchasePrice': 69234514513,
#   'institutionStraightPurchasePrice': 203477891603},
#  {'date': '2019-06-10 00:00:00',
#   'tradePrice': 2099.49,
#   'change': 'RISE',
#   'changePrice': 27.16,
#   'accTradeVolume': 457640,
#   'accTradePrice': 4214043,
#   'individualStraightPurchasePrice': -338433585668,
#   'foreignStraightPurchasePrice': 181865828210,
#   'institutionStraightPurchasePrice': 167291422679},
#  {'date': '2019-06-07 00:00:00',
#   'tradePrice': 2072.33,
#   'change': 'RISE',
#   'changePrice': 3.22,
#   'accTradeVolume': 368392,
#   'accTradePrice': 4347351,
#   'individualStraightPurchasePrice': -40059895436,
#   'foreignStraightPurchasePrice': -33318062866,
#   'institutionStraightPurchasePrice': 65786514521},
#  {'date': '2019-06-05 00:00:00',
#   'tradePrice': 2069.11,
#   'change': 'RISE',
#   'changePrice': 2.14,
#   'accTradeVolume': 380156,
#   'accTradePrice': 4506227,
#   'individualStraightPurchasePrice': 56665914597,
#   'foreignStraightPurchasePrice': -155874527876,
#   'institutionStraightPurchasePrice': 98474923591},
#  {'date': '2019-06-04 00:00:00',
#   'tradePrice': 2066.97,
#   'change': 'FALL',
#   'changePrice': 0.88,
#   'accTradeVolume': 435991,
#   'accTradePrice': 4841760,
#   'individualStraightPurchasePrice': 3220039078,
#   'foreignStraightPurchasePrice': -200164967877,
#   'institutionStraightPurchasePrice': 193534502808},
#  {'date': '2019-06-03 00:00:00',
#   'tradePrice': 2067.85,
#   'change': 'RISE',
#   'changePrice': 26.11,
#   'accTradeVolume': 387145,
#   'accTradePrice': 4640456,
#   'individualStraightPurchasePrice': -193325346081,
#   'foreignStraightPurchasePrice': 291395679762,
#   'institutionStraightPurchasePrice': -98572540911},
#  {'date': '2019-05-31 00:00:00',
#   'tradePrice': 2041.74,
#   'change': 'RISE',
#   'changePrice': 2.94,
#   'accTradeVolume': 439181,
#   'accTradePrice': 5039081,
#   'individualStraightPurchasePrice': -61281395162,
#   'foreignStraightPurchasePrice': 206222820885,
#   'institutionStraightPurchasePrice': -146046289829},
#  {'date': '2019-05-30 00:00:00',
#   'tradePrice': 2038.8,
#   'change': 'RISE',
#   'changePrice': 15.48,
#   'accTradeVolume': 461850,
#   'accTradePrice': 4978843,
#   'individualStraightPurchasePrice': -72021362520,
#   'foreignStraightPurchasePrice': 48406606231,
#   'institutionStraightPurchasePrice': 21685375521},
#  {'date': '2019-05-29 00:00:00',
#   'tradePrice': 2023.32,
#   'change': 'FALL',
#   'changePrice': 25.51,
#   'accTradeVolume': 380893,
#   'accTradePrice': 4686652,
#   'individualStraightPurchasePrice': 193190514658,
#   'foreignStraightPurchasePrice': -381531585556,
#   'institutionStraightPurchasePrice': 192717021057},
#  {'date': '2019-05-28 00:00:00',
#   'tradePrice': 2048.83,
#   'change': 'RISE',
#   'changePrice': 4.62,
#   'accTradeVolume': 494478,
#   'accTradePrice': 8080272,
#   'individualStraightPurchasePrice': 119853124842,
#   'foreignStraightPurchasePrice': -719057497035,
#   'institutionStraightPurchasePrice': 622718543279},
#  {'date': '2019-05-27 00:00:00',
#   'tradePrice': 2044.21,
#   'change': 'FALL',
#   'changePrice': 1.1,
#   'accTradeVolume': 351616,
#   'accTradePrice': 3506626,
#   'individualStraightPurchasePrice': 22898140761,
#   'foreignStraightPurchasePrice': -193988659151,
#   'institutionStraightPurchasePrice': 171052827451},
#  {'date': '2019-05-24 00:00:00',
#   'tradePrice': 2045.31,
#   'change': 'FALL',
#   'changePrice': 14.28,
#   'accTradeVolume': 480647,
#   'accTradePrice': 4581385,
#   'individualStraightPurchasePrice': -1257024852,
#   'foreignStraightPurchasePrice': -310212212215,
#   'institutionStraightPurchasePrice': 306930149255},
#  {'date': '2019-05-23 00:00:00',
#   'tradePrice': 2059.59,
#   'change': 'FALL',
#   'changePrice': 5.27,
#   'accTradeVolume': 509268,
#   'accTradePrice': 4819255,
#   'individualStraightPurchasePrice': 14972454518,
#   'foreignStraightPurchasePrice': 80916106150,
#   'institutionStraightPurchasePrice': -96210990635},
#  {'date': '2019-05-22 00:00:00',
#   'tradePrice': 2064.86,
#   'change': 'RISE',
#   'changePrice': 3.61,
#   'accTradeVolume': 509974,
#   'accTradePrice': 4637965,
#   'individualStraightPurchasePrice': 72815872315,
#   'foreignStraightPurchasePrice': 5300903349,
#   'institutionStraightPurchasePrice': -92457360141},
#  {'date': '2019-05-21 00:00:00',
#   'tradePrice': 2061.25,
#   'change': 'RISE',
#   'changePrice': 5.54,
#   'accTradeVolume': 526858,
#   'accTradePrice': 5272368,
#   'individualStraightPurchasePrice': -9482432039,
#   'foreignStraightPurchasePrice': 74360892295,
#   'institutionStraightPurchasePrice': -73025766952},
#  {'date': '2019-05-20 00:00:00',
#   'tradePrice': 2055.71,
#   'change': 'FALL',
#   'changePrice': 0.09,
#   'accTradeVolume': 640195,
#   'accTradePrice': 4889671,
#   'individualStraightPurchasePrice': 37013119336,
#   'foreignStraightPurchasePrice': -17762882496,
#   'institutionStraightPurchasePrice': 9568855074},
#  {'date': '2019-05-17 00:00:00',
#   'tradePrice': 2055.8,
#   'change': 'FALL',
#   'changePrice': 11.89,
#   'accTradeVolume': 537380,
#   'accTradePrice': 5378895,
#   'individualStraightPurchasePrice': 182498070316,
#   'foreignStraightPurchasePrice': -199417320948,
#   'institutionStraightPurchasePrice': 4245963256},
#  {'date': '2019-05-16 00:00:00',
#   'tradePrice': 2067.69,
#   'change': 'FALL',
#   'changePrice': 25.09,
#   'accTradeVolume': 745164,
#   'accTradePrice': 6042439,
#   'individualStraightPurchasePrice': 411406769493,
#   'foreignStraightPurchasePrice': -467905856517,
#   'institutionStraightPurchasePrice': 36705210008},
#  {'date': '2019-05-15 00:00:00',
#   'tradePrice': 2092.78,
#   'change': 'RISE',
#   'changePrice': 10.94,
#   'accTradeVolume': 577794,
#   'accTradePrice': 5052873,
#   'individualStraightPurchasePrice': 108230917953,
#   'foreignStraightPurchasePrice': -77646339392,
#   'institutionStraightPurchasePrice': -48430506945},
#  {'date': '2019-05-14 00:00:00',
#   'tradePrice': 2081.84,
#   'change': 'RISE',
#   'changePrice': 2.83,
#   'accTradeVolume': 696195,
#   'accTradePrice': 5865911,
#   'individualStraightPurchasePrice': -60314280562,
#   'foreignStraightPurchasePrice': -285078154873,
#   'institutionStraightPurchasePrice': 336784716653},
#  {'date': '2019-05-13 00:00:00',
#   'tradePrice': 2079.01,
#   'change': 'FALL',
#   'changePrice': 29.03,
#   'accTradeVolume': 505750,
#   'accTradePrice': 4601110,
#   'individualStraightPurchasePrice': 258103306140,
#   'foreignStraightPurchasePrice': -137329399592,
#   'institutionStraightPurchasePrice': -131377958377},
#  {'date': '2019-05-10 00:00:00',
#   'tradePrice': 2108.04,
#   'change': 'RISE',
#   'changePrice': 6.03,
#   'accTradeVolume': 714766,
#   'accTradePrice': 6407849,
#   'individualStraightPurchasePrice': 296859762301,
#   'foreignStraightPurchasePrice': -322345918362,
#   'institutionStraightPurchasePrice': 1311518506},
#  {'date': '2019-05-09 00:00:00',
#   'tradePrice': 2102.01,
#   'change': 'FALL',
#   'changePrice': 66.0,
#   'accTradeVolume': 743506,
#   'accTradePrice': 8236437,
#   'individualStraightPurchasePrice': 815694210535,
#   'foreignStraightPurchasePrice': -201507722282,
#   'institutionStraightPurchasePrice': -646501775948},
#  {'date': '2019-05-08 00:00:00',
#   'tradePrice': 2168.01,
#   'change': 'FALL',
#   'changePrice': 8.98,
#   'accTradeVolume': 456333,
#   'accTradePrice': 5170590,
#   'individualStraightPurchasePrice': 49273241101,
#   'foreignStraightPurchasePrice': 8971530080,
#   'institutionStraightPurchasePrice': -63134781086},
#  {'date': '2019-05-07 00:00:00',
#   'tradePrice': 2176.99,
#   'change': 'FALL',
#   'changePrice': 19.33,
#   'accTradeVolume': 484097,
#   'accTradePrice': 5467056,
#   'individualStraightPurchasePrice': 282298936839,
#   'foreignStraightPurchasePrice': 202645322790,
#   'institutionStraightPurchasePrice': -478652894928},
#  {'date': '2019-05-03 00:00:00',
#   'tradePrice': 2196.32,
#   'change': 'FALL',
#   'changePrice': 16.43,
#   'accTradeVolume': 617877,
#   'accTradePrice': 5297907,
#   'individualStraightPurchasePrice': 241687569701,
#   'foreignStraightPurchasePrice': 152121718314,
#   'institutionStraightPurchasePrice': -407528974046},
#  {'date': '2019-05-02 00:00:00',
#   'tradePrice': 2212.75,
#   'change': 'RISE',
#   'changePrice': 9.16,
#   'accTradeVolume': 369059,
#   'accTradePrice': 5026634,
#   'individualStraightPurchasePrice': -102498649019,
#   'foreignStraightPurchasePrice': 68075725901,
#   'institutionStraightPurchasePrice': 17008115424},
#  {'date': '2019-04-30 00:00:00',
#   'tradePrice': 2203.59,
#   'change': 'FALL',
#   'changePrice': 12.84,
#   'accTradeVolume': 381413,
#   'accTradePrice': 5697107,
#   'individualStraightPurchasePrice': 11873487785,
#   'foreignStraightPurchasePrice': 42947077654,
#   'institutionStraightPurchasePrice': -57260258409},
#  {'date': '2019-04-29 00:00:00',
#   'tradePrice': 2216.43,
#   'change': 'RISE',
#   'changePrice': 37.12,
#   'accTradeVolume': 380823,
#   'accTradePrice': 4985905,
#   'individualStraightPurchasePrice': -283315530073,
#   'foreignStraightPurchasePrice': 2993104677,
#   'institutionStraightPurchasePrice': 278467331316},
#  {'date': '2019-04-26 00:00:00',
#   'tradePrice': 2179.31,
#   'change': 'FALL',
#   'changePrice': 11.19,
#   'accTradeVolume': 570172,
#   'accTradePrice': 5346145,
#   'individualStraightPurchasePrice': 140108495541,
#   'foreignStraightPurchasePrice': 35494453987,
#   'institutionStraightPurchasePrice': -184407081264},
#  {'date': '2019-04-25 00:00:00',
#   'tradePrice': 2190.5,
#   'change': 'FALL',
#   'changePrice': 10.53,
#   'accTradeVolume': 441137,
#   'accTradePrice': 5610697,
#   'individualStraightPurchasePrice': 62920883969,
#   'foreignStraightPurchasePrice': -16463182533,
#   'institutionStraightPurchasePrice': -44641373862},
#  {'date': '2019-04-24 00:00:00',
#   'tradePrice': 2201.03,
#   'change': 'FALL',
#   'changePrice': 19.48,
#   'accTradeVolume': 575099,
#   'accTradePrice': 6342430,
#   'individualStraightPurchasePrice': 403028594977,
#   'foreignStraightPurchasePrice': 23034738836,
#   'institutionStraightPurchasePrice': -421394870096},
#  {'date': '2019-04-23 00:00:00',
#   'tradePrice': 2220.51,
#   'change': 'RISE',
#   'changePrice': 3.86,
#   'accTradeVolume': 481177,
#   'accTradePrice': 4922937,
#   'individualStraightPurchasePrice': 18049645895,
#   'foreignStraightPurchasePrice': 40678552070,
#   'institutionStraightPurchasePrice': -70749670286},
#  {'date': '2019-04-22 00:00:00',
#   'tradePrice': 2216.65,
#   'change': 'RISE',
#   'changePrice': 0.5,
#   'accTradeVolume': 493984,
#   'accTradePrice': 4639971,
#   'individualStraightPurchasePrice': 70187801687,
#   'foreignStraightPurchasePrice': -18622408526,
#   'institutionStraightPurchasePrice': -50248894428},
#  {'date': '2019-04-19 00:00:00',
#   'tradePrice': 2216.15,
#   'change': 'RISE',
#   'changePrice': 2.38,
#   'accTradeVolume': 525263,
#   'accTradePrice': 4965672,
#   'individualStraightPurchasePrice': 17773810717,
#   'foreignStraightPurchasePrice': -56699188826,
#   'institutionStraightPurchasePrice': 35110638501},
#  {'date': '2019-04-18 00:00:00',
#   'tradePrice': 2213.77,
#   'change': 'FALL',
#   'changePrice': 32.12,
#   'accTradeVolume': 573343,
#   'accTradePrice': 6501103,
#   'individualStraightPurchasePrice': 295948651490,
#   'foreignStraightPurchasePrice': -132046178719,
#   'institutionStraightPurchasePrice': -129047839794},
#  {'date': '2019-04-17 00:00:00',
#   'tradePrice': 2245.89,
#   'change': 'FALL',
#   'changePrice': 2.74,
#   'accTradeVolume': 452474,
#   'accTradePrice': 5586183,
#   'individualStraightPurchasePrice': -58901374367,
#   'foreignStraightPurchasePrice': 75629794263,
#   'institutionStraightPurchasePrice': 1430687865},
#  {'date': '2019-04-16 00:00:00',
#   'tradePrice': 2248.63,
#   'change': 'RISE',
#   'changePrice': 5.75,
#   'accTradeVolume': 569056,
#   'accTradePrice': 7083490,
#   'individualStraightPurchasePrice': -94868400197,
#   'foreignStraightPurchasePrice': 152726915563,
#   'institutionStraightPurchasePrice': -53930385890},
#  {'date': '2019-04-15 00:00:00',
#   'tradePrice': 2242.88,
#   'change': 'RISE',
#   'changePrice': 9.43,
#   'accTradeVolume': 404160,
#   'accTradePrice': 6668128,
#   'individualStraightPurchasePrice': 46570721080,
#   'foreignStraightPurchasePrice': 178112279612,
#   'institutionStraightPurchasePrice': -218897655932},
#  {'date': '2019-04-12 00:00:00',
#   'tradePrice': 2233.45,
#   'change': 'RISE',
#   'changePrice': 9.01,
#   'accTradeVolume': 449634,
#   'accTradePrice': 6098417,
#   'individualStraightPurchasePrice': -165725108045,
#   'foreignStraightPurchasePrice': 244644342119,
#   'institutionStraightPurchasePrice': -55843655377},
#  {'date': '2019-04-11 00:00:00',
#   'tradePrice': 2224.44,
#   'change': 'RISE',
#   'changePrice': 0.05,
#   'accTradeVolume': 402016,
#   'accTradePrice': 6022086,
#   'individualStraightPurchasePrice': -151212427472,
#   'foreignStraightPurchasePrice': 320810018251,
#   'institutionStraightPurchasePrice': -160584461009},
#  {'date': '2019-04-10 00:00:00',
#   'tradePrice': 2224.39,
#   'change': 'RISE',
#   'changePrice': 10.83,
#   'accTradeVolume': 399694,
#   'accTradePrice': 5135093,
#   'individualStraightPurchasePrice': -227976572662,
#   'foreignStraightPurchasePrice': -3263701331,
#   'institutionStraightPurchasePrice': 233451456344},
#  {'date': '2019-04-09 00:00:00',
#   'tradePrice': 2213.56,
#   'change': 'RISE',
#   'changePrice': 2.96,
#   'accTradeVolume': 414809,
#   'accTradePrice': 4904129,
#   'individualStraightPurchasePrice': -174029817368,
#   'foreignStraightPurchasePrice': 208962853800,
#   'institutionStraightPurchasePrice': -33162736361},
#  {'date': '2019-04-08 00:00:00',
#   'tradePrice': 2210.6,
#   'change': 'RISE',
#   'changePrice': 0.99,
#   'accTradeVolume': 347910,
#   'accTradePrice': 4660047,
#   'individualStraightPurchasePrice': -118114575698,
#   'foreignStraightPurchasePrice': 273084340534,
#   'institutionStraightPurchasePrice': -156559329796},
#  {'date': '2019-04-05 00:00:00',
#   'tradePrice': 2209.61,
#   'change': 'RISE',
#   'changePrice': 3.08,
#   'accTradeVolume': 517153,
#   'accTradePrice': 4215786,
#   'individualStraightPurchasePrice': -154424383825,
#   'foreignStraightPurchasePrice': 99629969828,
#   'institutionStraightPurchasePrice': 61566930966},
#  {'date': '2019-04-04 00:00:00',
#   'tradePrice': 2206.53,
#   'change': 'RISE',
#   'changePrice': 3.26,
#   'accTradeVolume': 431013,
#   'accTradePrice': 4857554,
#   'individualStraightPurchasePrice': -379675421091,
#   'foreignStraightPurchasePrice': 244857022773,
#   'institutionStraightPurchasePrice': 137828261411},
#  {'date': '2019-04-03 00:00:00',
#   'tradePrice': 2203.27,
#   'change': 'RISE',
#   'changePrice': 26.09,
#   'accTradeVolume': 358644,
#   'accTradePrice': 5466968,
#   'individualStraightPurchasePrice': -464376579788,
#   'foreignStraightPurchasePrice': 143111292991,
#   'institutionStraightPurchasePrice': 200828177419},
#  {'date': '2019-04-02 00:00:00',
#   'tradePrice': 2177.18,
#   'change': 'RISE',
#   'changePrice': 8.9,
#   'accTradeVolume': 257453,
#   'accTradePrice': 4247457,
#   'individualStraightPurchasePrice': -103600430646,
#   'foreignStraightPurchasePrice': 273406478933,
#   'institutionStraightPurchasePrice': -150581917969},
#  {'date': '2019-04-01 00:00:00',
#   'tradePrice': 2168.28,
#   'change': 'RISE',
#   'changePrice': 27.61,
#   'accTradeVolume': 263312,
#   'accTradePrice': 4365111,
#   'individualStraightPurchasePrice': -438066169858,
#   'foreignStraightPurchasePrice': 249088851263,
#   'institutionStraightPurchasePrice': 184589671919},
#  {'date': '2019-03-29 00:00:00',
#   'tradePrice': 2140.67,
#   'change': 'RISE',
#   'changePrice': 12.57,
#   'accTradeVolume': 364618,
#   'accTradePrice': 5248941,
#   'individualStraightPurchasePrice': -156006725386,
#   'foreignStraightPurchasePrice': 89041649012,
#   'institutionStraightPurchasePrice': 59696632751},
#  {'date': '2019-03-28 00:00:00',
#   'tradePrice': 2128.1,
#   'change': 'FALL',
#   'changePrice': 17.52,
#   'accTradeVolume': 288036,
#   'accTradePrice': 4403905,
#   'individualStraightPurchasePrice': 83696655492,
#   'foreignStraightPurchasePrice': -13904251094,
#   'institutionStraightPurchasePrice': -83176888246},
#  {'date': '2019-03-27 00:00:00',
#   'tradePrice': 2145.62,
#   'change': 'FALL',
#   'changePrice': 3.18,
#   'accTradeVolume': 363169,
#   'accTradePrice': 4490155,
#   'individualStraightPurchasePrice': 19189157579,
#   'foreignStraightPurchasePrice': -156137630355,
#   'institutionStraightPurchasePrice': 120182884108},
#  {'date': '2019-03-26 00:00:00',
#   'tradePrice': 2148.8,
#   'change': 'RISE',
#   'changePrice': 3.94,
#   'accTradeVolume': 301253,
#   'accTradePrice': 4248900,
#   'individualStraightPurchasePrice': 155665665386,
#   'foreignStraightPurchasePrice': 37396934512,
#   'institutionStraightPurchasePrice': -191513709988},
#  {'date': '2019-03-25 00:00:00',
#   'tradePrice': 2144.86,
#   'change': 'FALL',
#   'changePrice': 42.09,
#   'accTradeVolume': 307071,
#   'accTradePrice': 4136472,
#   'individualStraightPurchasePrice': 269204398460,
#   'foreignStraightPurchasePrice': -70853127031,
#   'institutionStraightPurchasePrice': -219094912901},
#  {'date': '2019-03-22 00:00:00',
#   'tradePrice': 2186.95,
#   'change': 'RISE',
#   'changePrice': 2.07,
#   'accTradeVolume': 333617,
#   'accTradePrice': 6881722,
#   'individualStraightPurchasePrice': 47138478352,
#   'foreignStraightPurchasePrice': 501319850079,
#   'institutionStraightPurchasePrice': -561768759655},
#  {'date': '2019-03-21 00:00:00',
#   'tradePrice': 2184.88,
#   'change': 'RISE',
#   'changePrice': 7.78,
#   'accTradeVolume': 342747,
#   'accTradePrice': 6229925,
#   'individualStraightPurchasePrice': -326383527941,
#   'foreignStraightPurchasePrice': 484065339759,
#   'institutionStraightPurchasePrice': -151526567122},
#  {'date': '2019-03-20 00:00:00',
#   'tradePrice': 2177.1,
#   'change': 'FALL',
#   'changePrice': 0.52,
#   'accTradeVolume': 317606,
#   'accTradePrice': 4175741,
#   'individualStraightPurchasePrice': 85576985458,
#   'foreignStraightPurchasePrice': -123654088780,
#   'institutionStraightPurchasePrice': 38732175899},
#  {'date': '2019-03-19 00:00:00',
#   'tradePrice': 2177.62,
#   'change': 'FALL',
#   'changePrice': 1.87,
#   'accTradeVolume': 319702,
#   'accTradePrice': 3867859,
#   'individualStraightPurchasePrice': 36930310648,
#   'foreignStraightPurchasePrice': -12413032485,
#   'institutionStraightPurchasePrice': -15797411779},
#  {'date': '2019-03-18 00:00:00',
#   'tradePrice': 2179.49,
#   'change': 'RISE',
#   'changePrice': 3.38,
#   'accTradeVolume': 257951,
#   'accTradePrice': 4093226,
#   'individualStraightPurchasePrice': -186777269431,
#   'foreignStraightPurchasePrice': -48787769406,
#   'institutionStraightPurchasePrice': 228677329333},
#  {'date': '2019-03-15 00:00:00',
#   'tradePrice': 2176.11,
#   'change': 'RISE',
#   'changePrice': 20.43,
#   'accTradeVolume': 387135,
#   'accTradePrice': 6821323,
#   'individualStraightPurchasePrice': -496308808713,
#   'foreignStraightPurchasePrice': -134219016142,
#   'institutionStraightPurchasePrice': 628388384084},
#  {'date': '2019-03-14 00:00:00',
#   'tradePrice': 2155.68,
#   'change': 'RISE',
#   'changePrice': 7.27,
#   'accTradeVolume': 341009,
#   'accTradePrice': 5882524,
#   'individualStraightPurchasePrice': 141640536139,
#   'foreignStraightPurchasePrice': 286699994288,
#   'institutionStraightPurchasePrice': -434371391530},
#  {'date': '2019-03-13 00:00:00',
#   'tradePrice': 2148.41,
#   'change': 'FALL',
#   'changePrice': 8.77,
#   'accTradeVolume': 285600,
#   'accTradePrice': 4088450,
#   'individualStraightPurchasePrice': 95657129720,
#   'foreignStraightPurchasePrice': 100064556811,
#   'institutionStraightPurchasePrice': -203107947266},
#  {'date': '2019-03-12 00:00:00',
#   'tradePrice': 2157.18,
#   'change': 'RISE',
#   'changePrice': 19.08,
#   'accTradeVolume': 355282,
#   'accTradePrice': 4222805,
#   'individualStraightPurchasePrice': -22480661728,
#   'foreignStraightPurchasePrice': -2304218047,
#   'institutionStraightPurchasePrice': 82392482069},
#  {'date': '2019-03-11 00:00:00',
#   'tradePrice': 2138.1,
#   'change': 'RISE',
#   'changePrice': 0.66,
#   'accTradeVolume': 272103,
#   'accTradePrice': 4077476,
#   'individualStraightPurchasePrice': 89359044451,
#   'foreignStraightPurchasePrice': -179309876147,
#   'institutionStraightPurchasePrice': 16639730580},
#  {'date': '2019-03-08 00:00:00',
#   'tradePrice': 2137.44,
#   'change': 'FALL',
#   'changePrice': 28.35,
#   'accTradeVolume': 313314,
#   'accTradePrice': 4497331,
#   'individualStraightPurchasePrice': 293213295508,
#   'foreignStraightPurchasePrice': -173863396395,
#   'institutionStraightPurchasePrice': -127447461480},
#  {'date': '2019-03-07 00:00:00',
#   'tradePrice': 2165.79,
#   'change': 'FALL',
#   'changePrice': 9.81,
#   'accTradeVolume': 292578,
#   'accTradePrice': 4858918,
#   'individualStraightPurchasePrice': 110774668511,
#   'foreignStraightPurchasePrice': 397749809,
#   'institutionStraightPurchasePrice': -112972757189},
#  {'date': '2019-03-06 00:00:00',
#   'tradePrice': 2175.6,
#   'change': 'FALL',
#   'changePrice': 3.63,
#   'accTradeVolume': 328943,
#   'accTradePrice': 4828088,
#   'individualStraightPurchasePrice': 65444620090,
#   'foreignStraightPurchasePrice': 5960479949,
#   'institutionStraightPurchasePrice': -53182364884},
#  {'date': '2019-03-05 00:00:00',
#   'tradePrice': 2179.23,
#   'change': 'FALL',
#   'changePrice': 11.43,
#   'accTradeVolume': 313145,
#   'accTradePrice': 4980940,
#   'individualStraightPurchasePrice': 244352695932,
#   'foreignStraightPurchasePrice': -157017695710,
#   'institutionStraightPurchasePrice': -91932649815},
#  {'date': '2019-03-04 00:00:00',
#   'tradePrice': 2190.66,
#   'change': 'FALL',
#   'changePrice': 4.78,
#   'accTradeVolume': 373166,
#   'accTradePrice': 6405237,
#   'individualStraightPurchasePrice': 40328329456,
#   'foreignStraightPurchasePrice': -131953894891,
#   'institutionStraightPurchasePrice': 76676527211},
#  {'date': '2019-02-28 00:00:00',
#   'tradePrice': 2195.44,
#   'change': 'FALL',
#   'changePrice': 39.35,
#   'accTradeVolume': 510022,
#   'accTradePrice': 8307295,
#   'individualStraightPurchasePrice': -61784182288,
#   'foreignStraightPurchasePrice': -253615330622,
#   'institutionStraightPurchasePrice': 316907947344},
#  {'date': '2019-02-27 00:00:00',
#   'tradePrice': 2234.79,
#   'change': 'RISE',
#   'changePrice': 8.19,
#   'accTradeVolume': 301513,
#   'accTradePrice': 4914612,
#   'individualStraightPurchasePrice': -111560459992,
#   'foreignStraightPurchasePrice': -57281941122,
#   'institutionStraightPurchasePrice': 151857839470},
#  {'date': '2019-02-26 00:00:00',
#   'tradePrice': 2226.6,
#   'change': 'FALL',
#   'changePrice': 5.96,
#   'accTradeVolume': 331962,
#   'accTradePrice': 5024237,
#   'individualStraightPurchasePrice': -29933232288,
#   'foreignStraightPurchasePrice': 52587149454,
#   'institutionStraightPurchasePrice': -11130391018},
#  {'date': '2019-02-25 00:00:00',
#   'tradePrice': 2232.56,
#   'change': 'RISE',
#   'changePrice': 2.06,
#   'accTradeVolume': 339233,
#   'accTradePrice': 4689860,
#   'individualStraightPurchasePrice': 9115915650,
#   'foreignStraightPurchasePrice': -79616430722,
#   'institutionStraightPurchasePrice': 80275227515},
#  {'date': '2019-02-22 00:00:00',
#   'tradePrice': 2230.5,
#   'change': 'RISE',
#   'changePrice': 1.84,
#   'accTradeVolume': 409310,
#   'accTradePrice': 4645184,
#   'individualStraightPurchasePrice': -34206063862,
#   'foreignStraightPurchasePrice': -4489698991,
#   'institutionStraightPurchasePrice': 40129915874},
#  {'date': '2019-02-21 00:00:00',
#   'tradePrice': 2228.66,
#   'change': 'FALL',
#   'changePrice': 1.1,
#   'accTradeVolume': 382510,
#   'accTradePrice': 5480909,
#   'individualStraightPurchasePrice': -11715660173,
#   'foreignStraightPurchasePrice': 208350642084,
#   'institutionStraightPurchasePrice': -204832647512},
#  {'date': '2019-02-20 00:00:00',
#   'tradePrice': 2229.76,
#   'change': 'RISE',
#   'changePrice': 24.13,
#   'accTradeVolume': 374342,
#   'accTradePrice': 5948416,
#   'individualStraightPurchasePrice': -430005578127,
#   'foreignStraightPurchasePrice': 434537456972,
#   'institutionStraightPurchasePrice': -7622944609},
#  {'date': '2019-02-19 00:00:00',
#   'tradePrice': 2205.63,
#   'change': 'FALL',
#   'changePrice': 5.26,
#   'accTradeVolume': 389093,
#   'accTradePrice': 4534559,
#   'individualStraightPurchasePrice': -138825492949,
#   'foreignStraightPurchasePrice': -7595622702,
#   'institutionStraightPurchasePrice': 141943794647},
#  {'date': '2019-02-18 00:00:00',
#   'tradePrice': 2210.89,
#   'change': 'RISE',
#   'changePrice': 14.8,
#   'accTradeVolume': 314370,
#   'accTradePrice': 4668186,
#   'individualStraightPurchasePrice': -324089726464,
#   'foreignStraightPurchasePrice': 45572631937,
#   'institutionStraightPurchasePrice': 266392639430},
#  {'date': '2019-02-15 00:00:00',
#   'tradePrice': 2196.09,
#   'change': 'FALL',
#   'changePrice': 29.76,
#   'accTradeVolume': 400591,
#   'accTradePrice': 5097630,
#   'individualStraightPurchasePrice': 198483974390,
#   'foreignStraightPurchasePrice': -177735141507,
#   'institutionStraightPurchasePrice': -44941294626},
#  {'date': '2019-02-14 00:00:00',
#   'tradePrice': 2225.85,
#   'change': 'RISE',
#   'changePrice': 24.37,
#   'accTradeVolume': 573362,
#   'accTradePrice': 6426022,
#   'individualStraightPurchasePrice': -192622047092,
#   'foreignStraightPurchasePrice': -47598481932,
#   'institutionStraightPurchasePrice': 242683671125},
#  {'date': '2019-02-13 00:00:00',
#   'tradePrice': 2201.48,
#   'change': 'RISE',
#   'changePrice': 11.01,
#   'accTradeVolume': 421989,
#   'accTradePrice': 5585494,
#   'individualStraightPurchasePrice': -126050958059,
#   'foreignStraightPurchasePrice': -30643242333,
#   'institutionStraightPurchasePrice': 134305305447},
#  {'date': '2019-02-12 00:00:00',
#   'tradePrice': 2190.47,
#   'change': 'RISE',
#   'changePrice': 9.74,
#   'accTradeVolume': 429940,
#   'accTradePrice': 5929463,
#   'individualStraightPurchasePrice': -14710983697,
#   'foreignStraightPurchasePrice': -37530351094,
#   'institutionStraightPurchasePrice': 46887464654},
#  {'date': '2019-02-11 00:00:00',
#   'tradePrice': 2180.73,
#   'change': 'RISE',
#   'changePrice': 3.68,
#   'accTradeVolume': 406059,
#   'accTradePrice': 5327610,
#   'individualStraightPurchasePrice': 115581612435,
#   'foreignStraightPurchasePrice': -57340663493,
#   'institutionStraightPurchasePrice': -73260074148},
#  {'date': '2019-02-08 00:00:00',
#   'tradePrice': 2177.05,
#   'change': 'FALL',
#   'changePrice': 26.37,
#   'accTradeVolume': 391029,
#   'accTradePrice': 5728529,
#   'individualStraightPurchasePrice': 331271999382,
#   'foreignStraightPurchasePrice': -280259032809,
#   'institutionStraightPurchasePrice': -72546332158}]

# %% [markdown]
# * 문자열 메소드인 join을 사용하여 콤마를 붙여서 출력해봅시다

# %%
for content in json_r['data']:
    print (",".join([str(x) for x in list(content.values())]))
# Out:
# 2019-07-03 00:00:00,2113.28,FALL,8.74,180753,1415097,25435352963,-51579856319,28986343951
# 2019-07-02 00:00:00,2122.02,FALL,7.72,460830,4107541,24006908061,34321459071,-51500525649
# 2019-07-01 00:00:00,2129.74,FALL,0.88,412291,4730192,-19121687014,154486503785,6138187770
# 2019-06-28 00:00:00,2130.62,FALL,3.7,537274,4282404,-199483658718,312263760802,-109684798220
# 2019-06-27 00:00:00,2134.32,RISE,12.47,644900,5122462,-405768338937,155887532000,267089212849
# 2019-06-26 00:00:00,2121.85,RISE,0.21,736851,4455865,-73635556218,16452829619,60969038311
# 2019-06-25 00:00:00,2121.64,FALL,4.69,642999,4249731,-21135872689,27387982,8844220728
# 2019-06-24 00:00:00,2126.33,RISE,0.71,669639,4054920,-72774648738,-99250349566,163711527766
# 2019-06-21 00:00:00,2125.62,FALL,5.67,692027,5226303,118735540006,13280881909,-130936554570
# 2019-06-20 00:00:00,2131.29,RISE,6.51,1007158,3994784,-148542907457,-18322575414,164450625338
# 2019-06-19 00:00:00,2124.78,RISE,26.07,862980,4984533,-460489624085,300430954174,169276816225
# 2019-06-18 00:00:00,2098.71,RISE,7.98,600964,4579592,-129501534187,261816928364,86891545505
# 2019-06-17 00:00:00,2090.73,FALL,4.68,561550,4255706,7838261537,-150088594638,140374240557
# 2019-06-14 00:00:00,2095.41,FALL,7.74,473370,4716415,157690404429,-69368483603,-92172949183
# 2019-06-13 00:00:00,2103.15,FALL,5.6,553393,5998223,131707587548,-165712563303,51511213419
# 2019-06-12 00:00:00,2108.75,FALL,3.06,693507,4661009,-96265719945,-2329064115,101634418700
    f.write(",".join(list(content.keys())) + "\n")
    for content in json_r['data']:
        f.write(",".join([str(x) for x in list(content.values())]) + "\n")

# %% [markdown]
# ## pandas의 DataFrame를 사용하여 쉽게 저장하기

# %%
import pandas as pd

# %%
pd.DataFrame(json_r['data'])
# Out:
#     accTradePrice  accTradeVolume change  changePrice                 date  \
# 0         1415097          180753   FALL         8.74  2019-07-03 00:00:00
# 1         4107541          460830   FALL         7.72  2019-07-02 00:00:00
# 2         4730192          412291   FALL         0.88  2019-07-01 00:00:00
# 3         4282404          537274   FALL         3.70  2019-06-28 00:00:00
# 4         5122462          644900   RISE        12.47  2019-06-27 00:00:00
# 5         4455865          736851   RISE         0.21  2019-06-26 00:00:00
# 6         4249731          642999   FALL         4.69  2019-06-25 00:00:00
# 7         4054920          669639   RISE         0.71  2019-06-24 00:00:00
# 8         5226303          692027   FALL         5.67  2019-06-21 00:00:00
# 9         3994784         1007158   RISE         6.51  2019-06-20 00:00:00
# 10        4984533          862980   RISE        26.07  2019-06-19 00:00:00
# 11        4579592          600964   RISE         7.98  2019-06-18 00:00:00
# 12        4255706          561550   FALL         4.68  2019-06-17 00:00:00
# 13        4716415          473370   FALL         7.74  2019-06-14 00:00:00
# 14        5998223          553393   FALL         5.60  2019-06-13 00:00:00
# 15        4661009          693507   FALL         3.06  2019-06-12 00:00:00
# 16        4276695          550740   RISE        12.32  2019-06-11 00:00:00
# 17        4214043          457640   RISE        27.16  2019-06-10 00:00:00
# 18        4347351          368392   RISE         3.22  2019-06-07 00:00:00
# 19        4506227          380156   RISE         2.14  2019-06-05 00:00:00
# 20        4841760          435991   FALL         0.88  2019-06-04 00:00:00
# 21        4640456          387145   RISE        26.11  2019-06-03 00:00:00
# 22        5039081          439181   RISE         2.94  2019-05-31 00:00:00
# 23        4978843          461850   RISE        15.48  2019-05-30 00:00:00
# 24        4686652          380893   FALL        25.51  2019-05-29 00:00:00
# 25        8080272          494478   RISE         4.62  2019-05-28 00:00:00
# 26        3506626          351616   FALL         1.10  2019-05-27 00:00:00
# 27        4581385          480647   FALL        14.28  2019-05-24 00:00:00
# 28        4819255          509268   FALL         5.27  2019-05-23 00:00:00
# 29        4637965          509974   RISE         3.61  2019-05-22 00:00:00
# ..            ...             ...    ...          ...                  ...
# 70        6881722          333617   RISE         2.07  2019-03-22 00:00:00
# 71        6229925          342747   RISE         7.78  2019-03-21 00:00:00
# 72        4175741          317606   FALL         0.52  2019-03-20 00:00:00
# 73        3867859          319702   FALL         1.87  2019-03-19 00:00:00
# 74        4093226          257951   RISE         3.38  2019-03-18 00:00:00
# 75        6821323          387135   RISE        20.43  2019-03-15 00:00:00
# 76        5882524          341009   RISE         7.27  2019-03-14 00:00:00
# 77        4088450          285600   FALL         8.77  2019-03-13 00:00:00
# 78        4222805          355282   RISE        19.08  2019-03-12 00:00:00
# 79        4077476          272103   RISE         0.66  2019-03-11 00:00:00
# 80        4497331          313314   FALL        28.35  2019-03-08 00:00:00
# 90                  208350642084                     -11715660173
# 91                  434537456972                    -430005578127
# 92                   -7595622702                    -138825492949
# 93                   45572631937                    -324089726464
# 94                 -177735141507                     198483974390
# 95                  -47598481932                    -192622047092
# 96                  -30643242333                    -126050958059
# 97                  -37530351094                     -14710983697
# 98                  -57340663493                     115581612435
# 99                 -280259032809                     331271999382
#
#     institutionStraightPurchasePrice  tradePrice
# 0                        28986343951     2113.28
# 1                       -51500525649     2122.02
# 2                         6138187770     2129.74
# 3                      -109684798220     2130.62
# 4                       267089212849     2134.32
# 5                        60969038311     2121.85
# 6                         8844220728     2121.64
# 7                       163711527766     2126.33
# 8                      -130936554570     2125.62
# 9                       164450625338     2131.29
# 10                      169276816225     2124.78
# 11                       86891545505     2098.71
# 12                      140374240557     2090.73
# 13                      -92172949183     2095.41
# 14                       51511213419     2103.15
# 15                      101634418700     2108.75
# 16                      203477891603     2111.81
# 17                      167291422679     2099.49
# 18                       65786514521     2072.33
# 19                       98474923591     2069.11
# 20                      193534502808     2066.97
# 21                      -98572540911     2067.85
# 22                     -146046289829     2041.74
# 23                       21685375521     2038.80
# 24                      192717021057     2023.32
# 25                      622718543279     2048.83
# 26                      171052827451     2044.21
# 27                      306930149255     2045.31
# 28                      -96210990635     2059.59
# 29                      -92457360141     2064.86
# ..                               ...         ...
# 70                     -561768759655     2186.95
# 71                     -151526567122     2184.88
# 72                       38732175899     2177.10
# 73                      -15797411779     2177.62
# 74                      228677329333     2179.49
# 75                      628388384084     2176.11
# 76                     -434371391530     2155.68
# 77                     -203107947266     2148.41
# 78                       82392482069     2157.18
# 79                       16639730580     2138.10
# 80                     -127447461480     2137.44
# 81                     -112972757189     2165.79
# 82                      -53182364884     2175.60
# 83                      -91932649815     2179.23
# 84                       76676527211     2190.66
# 85                      316907947344     2195.44
# 86                      151857839470     2234.79
# 87                      -11130391018     2226.60
# 88                       80275227515     2232.56
# 89                       40129915874     2230.50
# 90                     -204832647512     2228.66
# 91                       -7622944609     2229.76
# 92                      141943794647     2205.63
# 93                      266392639430     2210.89
# 94                      -44941294626     2196.09
# 95                      242683671125     2225.85
# 96                      134305305447     2201.48
# 97                       46887464654     2190.47
# 98                      -73260074148     2180.73
# 99                      -72546332158     2177.05
#
# [100 rows x 9 columns]

# %% [markdown]
# * to_csv() 메소드를 사용하면 csv 형태로 쉽게 저장할 수 있습니다.

# %%
pd.DataFrame(json_r['data']).to_csv("./df_daum_kospi.csv", index=False)

# %% [markdown]
# ## 수집한 금액 데이터에 콤마가 포함되어 있을 경우

# %%
from bs4 import BeautifulSoup

# %%
url = "https://finance.naver.com/marketindex/exchangeList.nhn"

r = requests.get(url)
bs = BeautifulSoup(r.text, 'html.parser')

with open("./exchange_rate.csv", "w", encoding='utf-8-sig') as f:    
    for idx, cont in enumerate(bs.findAll("tr")):
        if(idx>1):
            bs2 = cont.findAll("td")
            for cont2 in bs2:
                f.write(cont2.text.strip() +",")
            f.write("\n")

# %% [markdown]
# * 해당 파일을 열어 보면 원하는 모양이 아닌 것을 확인할 수 있습니다.
# * 쉽게 저장하기 위해서 아래 csv 라이브러리를 사용합니다.

# %% [markdown]
# ### csv 모듈 사용하기

# %%
import csv

# %% [markdown]
# * csv.writer()는 파일을 쓰는 기능을 합니다.

# %%
with open("exchange_rate_csv_module.csv", "w", encoding='utf-8-sig', newline='') as f:    
    filewrite = csv.writer(f, delimiter=",")
    for idx, cont in enumerate(bs.findAll("tr")):
        if(idx>1):
            bs2 = cont.findAll("td")
            total_txt = list()
            for cont2 in bs2:
                total_txt.append(cont2.text.strip())
            filewrite.writerow(total_txt)

# %% [markdown]
# #### 읽어오기

# %% [markdown]
# * csv.reader() 파일에서 데이터를 읽어옵니다.

# %%
with open("./exchange_rate_csv_module.csv", "r", encoding='utf-8-sig') as f : 
    filereader = csv.reader(f, delimiter=',')
    for content in filereader:
        print (content)
# Out:
# ['미국 USD', '1,170.20', '1,190.67', '1,149.73', '1,181.60', '1,158.80', '1.000']
# ['유럽연합 EUR', '1,321.51', '1,347.80', '1,295.22', '1,334.72', '1,308.30', '1.129']
# ['일본 JPY (100엔)', '1,087.60', '1,106.63', '1,068.57', '1,098.25', '1,076.95', '0.929']
# ['중국 CNY', '169.91', '178.40', '161.42', '171.60', '168.22', '0.145']
# ['홍콩 HKD', '150.06', '153.01', '147.11', '151.56', '148.56', '0.128']
# ['대만 TWD', '37.65', '42.58', '35.02', '0.00', '0.00', '0.032']
# ['영국 GBP', '1,474.04', '1,503.07', '1,445.01', '1,488.78', '1,459.30', '1.260']
# ['오만 OMR', '3,039.56', '3,310.08', '2,857.19', '0.00', '0.00', '2.598']
# ['캐나다 CAD', '893.49', '911.09', '875.89', '902.42', '884.56', '0.764']
# ['스위스 CHF', '1,189.59', '1,213.02', '1,166.16', '1,201.48', '1,177.70', '1.017']
# ['스웨덴 SEK', '125.42', '128.49', '122.35', '126.67', '124.17', '0.107']
# ['호주 AUD', '817.79', '833.90', '801.68', '825.96', '809.62', '0.699']
# ['뉴질랜드 NZD', '781.23', '796.62', '765.84', '789.04', '773.42', '0.668']
# ['체코 CZK', '51.93', '56.34', '47.26', '52.50', '51.36', '0.044']
# ['칠레 CLP', '1.72', '1.85', '1.59', '0.00', '0.00', '0.002']
# ['터키 TRY', '207.01', '0.00', '0.00', '209.28', '204.74', '0.177']
# ['몽골 MNT', '0.44', '0.00', '0.00', '0.00', '0.00', '0.000']
# ['이스라엘 ILS', '327.20', '359.92', '301.03', '0.00', '0.00', '0.280']
# ['덴마크 DKK', '177.05', '181.38', '172.72', '178.82', '175.28', '0.151']
# ['노르웨이 NOK', '136.62', '139.96', '133.28', '137.98', '135.26', '0.117']
# ['사우디아라비아 SAR', '312.04', '331.69', '290.51', '315.16', '308.92', '0.267']
# ['쿠웨이트 KWD', '3,851.88', '4,102.25', '3,543.73', '3,890.39', '3,813.37', '3.292']
# ['바레인 BHD', '3,103.98', '3,302.63', '2,855.67', '3,135.01', '3,072.95', '2.653']
# ['아랍에미리트 AED', '318.58', '336.10', '296.60', '321.76', '315.40', '0.272']
# ['요르단 JOD', '1,650.49', '1,797.38', '1,518.46', '0.00', '0.00', '1.410']
# ['이집트 EGP', '70.32', '0.00', '0.00', '0.00', '0.00', '0.060']
# ['태국 THB', '38.25', '40.16', '35.96', '38.63', '37.87', '0.033']
# ['싱가포르 SGD', '863.33', '880.51', '846.15', '871.96', '854.70', '0.738']
# ['말레이시아 MYR', '282.83', '300.64', '261.91', '0.00', '280.01', '0.242']
# ['인도네시아 IDR 100', '8.28', '8.85', '7.46', '8.36', '8.20', '0.007']
# ['카타르 QAR', '321.40', '0.00', '0.00', '0.00', '0.00', '0.275']
# ['카자흐스탄 KZT', '3.06', '0.00', '0.00', '0.00', '0.00', '0.003']
# ['브루나이 BND', '863.33', '897.86', '811.54', '0.00', '0.00', '0.738']
# ['인도 INR', '16.99', '0.00', '0.00', '0.00', '0.00', '0.015']
# ['파키스탄 PKR', '7.48', '0.00', '0.00', '0.00', '0.00', '0.006']
# ['방글라데시 BDT', '13.85', '0.00', '0.00', '0.00', '0.00', '0.012']
# ['필리핀 PHP', '22.86', '25.14', '20.99', '23.08', '22.64', '0.020']
# ['멕시코 MXN', '61.40', '67.54', '56.25', '62.01', '60.79', '0.053']
# ['브라질 BRL', '304.29', '335.32', '279.95', '0.00', '300.64', '0.260']
# ['베트남 VND 100', '5.04', '5.63', '4.45', '5.09', '4.99', '0.004']
# ['남아프리카 공화국 ZAR', '83.07', '88.05', '76.43', '84.06', '82.08', '0.071']
# ['러시아 RUB', '18.46', '19.75', '16.43', '18.64', '18.28', '0.016']
# ['헝가리 HUF', '4.09', '4.47', '3.77', '4.13', '4.05', '0.004']
# ['폴란드 PLN', '311.38', '336.29', '286.47', '314.80', '307.96', '0.266']

# %% [markdown]
# ## excel

# %% [markdown]
# * 엑셀에 저장하기 위해서 total에 데이터를 저장합니다.

# %%
total = []
with open("./exchange_rate_csv_module.csv", "r", encoding='utf-8-sig') as f : 
    filereader = csv.reader(f, delimiter=',')
    for content in filereader:
        total.append(content)

# %%
# 라이브러리를 import 한다. 단 Thrid Party이기 때문에 설치되어 있지 않으면 
# 매직 명령어를 사용하여 설치한다.
# !pip install xlsxwriter        
import xlsxwriter

# 파일을 생성한다. 
workbook = xlsxwriter.Workbook("xlsx_exchange_rate.xlsx")

# Sheet 이름을 정한다. 
worksheet = workbook.add_worksheet('환율정보')

# 컬럼의 넓이를 정할수 있다. 
worksheet.set_column('A:F', 20)

# Cell의 스타일을 지정할 수 있다. 
bold = workbook.add_format({'bold' : True})

for idx1, x1 in enumerate(total):
    for idx2, x2 in enumerate(x1):
        # write() 메소드는 실제 엑셀 파일에 기록하는 메소드이며, 
        # idx2, idx2 번째 위치에 x2의 값을 bold형태로 저장한다. 
        worksheet.write(idx1, idx2, x2, bold)
    
# 파일을 닫는다 
workbook.close()
